# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
previous = pd.read_csv('../raw-data/dseb63_previous_application.csv')
previous.head()
# Out:
#    SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 0     2030495     Consumer loans     1730.430          17145.0     17145.0
# 1     1696966     Consumer loans    68258.655        1800000.0   1754721.0
# 2     2154916     Consumer loans    12417.390         108400.5    119848.5
# 3     2802425         Cash loans    25188.615         607500.0    679671.0
# 4     1536272         Cash loans    21709.125         450000.0    512370.0
#
#    AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0               0.0          17145.0                   SATURDAY
# 1          180000.0        1800000.0                   SATURDAY
# 2               0.0         108400.5                     SUNDAY
# 3               NaN         607500.0                   THURSDAY
# 4               NaN         450000.0                  WEDNESDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  ...  CNT_PAYMENT  \
# ...

# %%
previous.sort_values('SK_ID_PREV', inplace=True)
previous.reset_index(drop=True, inplace=True)
previous.head()
# Out:
#    SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 0     1000001     Consumer loans     6404.310        58905.000     65124.0
# 1     1000003     Consumer loans     4951.350        47056.275     52641.0
# 2     1000004     Consumer loans     3391.110        35144.370     30586.5
# 3     1000005     Consumer loans    14713.605       123486.075    120307.5
# 4     1000007     Consumer loans    11246.805        78570.000     62856.0
#
#    AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0             0.000        58905.000                   THURSDAY
# 1             4.275        47056.275                     SUNDAY
# 2          7032.870        35144.370                   THURSDAY
# 3         12349.575       123486.075                   THURSDAY
# 4         15714.000        78570.000                     SUNDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  ...  CNT_PAYMENT  \
# ...

# %%
previous['SK_ID_PREV'].nunique() == len(previous)
# Out:
# True
